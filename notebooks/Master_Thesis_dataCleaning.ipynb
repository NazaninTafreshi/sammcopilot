# %% [markdown]
# # Data Prep

# %% [markdown]
# The following code converts all SAMM 2.0.0 to 2.1.0.

# %%
import os

def replace_in_ttl_files(directory):
    """
    Recursively find all .ttl files in the given directory, replace a string, rewrite the files
    
    Args:
    directory (str): The root directory to start searching from.
    
    """
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".ttl"):
                file_path = os.path.join(root, file)
                
                # Read file content
#                 print(file_path)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.readlines()  # Read file as a list of lines
                
                # Process each line
                new_content = []
                for line in content:
                    if line.strip().startswith('@'):
                        # Replace content
                        line = line.replace("urn:samm:org.eclipse.esmf.samm:characteristic:2.0.0#",
                                                        "urn:samm:org.eclipse.esmf.samm:characteristic:2.1.0#")

                        line = line.replace("urn:samm:org.eclipse.esmf.samm:entity:2.0.0#",
                                                        "urn:samm:org.eclipse.esmf.samm:entity:2.1.0#")

                        line = line.replace("urn:samm:org.eclipse.esmf.samm:meta-model:2.0.0#",
                                                        "urn:samm:org.eclipse.esmf.samm:meta-model:2.1.0#")

                        line = line.replace("urn:samm:org.eclipse.esmf.samm:unit:2.0.0#",
                                                        "urn:samm:org.eclipse.esmf.samm:unit:2.1.0#")
                    if line.strip().startswith('#'):
                        # Replace content
                        continue
                    new_content.append(line)
                # Write the updated content back to the file
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.writelines(new_content)


directory = 'D:/NMT Thesis/Dataset/content/sldt-semantic-models'

replace_in_ttl_files(directory)

# %% [markdown]
# Perform data split based on model name.

# %%
import os
from pathlib import Path

json_paths = []
ttl_paths = []
base_path = set()

clone_dir = 'D:\\NMT Thesis\\Dataset\\sldt-semantic-models'
for root, dirs, files in os.walk(clone_dir):
    for file in files:
          if file.endswith(".ttl"):
            ttl_path = os.path.relpath(os.path.join(root, file), clone_dir)
            ttl_paths.append(ttl_path)
            base_path.add(Path(ttl_path).parts[0])

# %%
ttl_paths
# Out:
# ['io.catenax.asset_tracker_links\\2.0.0\\AssetTrackerLinks.ttl',
#  'io.catenax.asset_tracker_links\\2.1.0\\AssetTrackerLinks.ttl',
#  'io.catenax.asset_tracker_links\\2.2.0\\AssetTrackerLinks.ttl',
#  'io.catenax.batch\\2.0.0\\Batch.ttl',
#  'io.catenax.batch\\2.0.1\\Batch.ttl',
#  'io.catenax.batch\\2.1.0\\Batch.ttl',
#  'io.catenax.batch\\2.1.1\\Batch.ttl',
#  'io.catenax.batch\\2.2.0\\Batch.ttl',
#  'io.catenax.batch\\2.2.1\\Batch.ttl',
#  'io.catenax.batch\\3.0.0\\Batch.ttl',
#  'io.catenax.batch\\3.1.0\\Batch.ttl',
#  'io.catenax.batch\\3.2.0\\Batch.ttl',
#  'io.catenax.battery.battery_pass\\4.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\4.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\4.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.product_description\\1.0.1\\ProductDescription.ttl',
#  'io.catenax.battery.product_description\\1.1.1\\ProductDescription.ttl',
#  'io.catenax.battery.product_description\\1.2.1\\ProductDescription.ttl',
#  'io.catenax.bom_as_specified\\1.0.1\\BomAsSpecified.ttl',
#  'io.catenax.bom_as_specified\\1.1.1\\BomAsSpecified.ttl',
#  'io.catenax.bom_as_specified\\1.2.1\\BomAsSpecified.ttl',
#  'io.catenax.certificate_of_destruction\\2.0.0\\CertificateOfDestruction.ttl',
#  'io.catenax.certificate_of_destruction\\2.1.0\\CertificateOfDestruction.ttl',
#  'io.catenax.certificate_of_dismantler\\1.0.1\\CertificateOfDismantler.ttl',
#  'io.catenax.certificate_of_dismantler\\1.1.1\\CertificateOfDismantler.ttl',
#  'io.catenax.certificate_of_dismantler\\1.2.1\\CertificateOfDismantler.ttl',
#  'io.catenax.certificate_signing_requests\\1.0.0\\CertificateSigningRequests.ttl',
#  'io.catenax.certificate_signing_requests\\1.1.0\\CertificateSigningRequests.ttl',
#  'io.catenax.certificate_signing_requests\\1.2.0\\CertificateSigningRequests.ttl',
#  'io.catenax.classified_load_spectrum\\2.0.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.classified_load_spectrum\\2.1.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.classified_load_spectrum\\2.2.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.customs_information\\1.0.0\\CustomsInformation.ttl',
#  'io.catenax.customs_information\\1.1.0\\CustomsInformation.ttl',
#  'io.catenax.customs_information\\1.2.0\\CustomsInformation.ttl',
#  'io.catenax.days_of_supply\\1.0.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\1.1.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\1.2.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.0.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.1.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.2.0\\DaysOfSupply.ttl',
#  'io.catenax.decomissioning_certificate\\2.0.0\\DecommissioningCertificate.ttl',
#  'io.catenax.decomissioning_certificate\\2.1.0\\DecommissioningCertificate.ttl',
#  'io.catenax.decomissioning_certificate\\2.2.0\\DecommissioningCertificate.ttl',
#  'io.catenax.delivery_information\\1.0.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\1.1.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\1.2.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.0.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.1.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.2.0\\DeliveryInformation.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.0.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.1.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.2.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.0.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.1.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.2.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.early_warning_notification\\1.0.0\\EarlyWarningNotification.ttl',
#  'io.catenax.early_warning_notification\\1.1.0\\EarlyWarningNotification.ttl',
#  'io.catenax.early_warning_notification\\1.2.0\\EarlyWarningNotification.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.0.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.1.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.2.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.0.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.1.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.2.0\\ElectricDrivePassport.ttl',
#  'io.catenax.eol_story\\2.0.0\\EndOfLife.ttl',
#  'io.catenax.eol_story\\2.1.0\\EndOfLife.ttl',
#  'io.catenax.eol_story\\2.2.0\\EndOfLife.ttl',
#  'io.catenax.essincident\\2.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\2.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\2.2.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.2.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.2.0\\EssIncident.ttl',
#  'io.catenax.failure_pattern\\1.0.0\\FailurePattern.ttl',
#  'io.catenax.failure_pattern\\1.1.0\\FailurePattern.ttl',
#  'io.catenax.failure_pattern\\1.2.0\\FailurePattern.ttl',
#  'io.catenax.fleet.claim_data\\2.0.0\\ClaimData.ttl',
#  'io.catenax.fleet.claim_data\\2.1.0\\ClaimData.ttl',
#  'io.catenax.fleet.claim_data\\2.2.0\\ClaimData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.0.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.1.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.2.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.vehicles\\1.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\1.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\1.2.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.2.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.3.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.4.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.5.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.2.0\\Vehicles.ttl',
#  'io.catenax.generic.digital_product_passport\\2.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\2.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\2.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.global_transport_label\\1.0.0\\GlobalTransportLabel.ttl',
#  'io.catenax.global_transport_label\\1.1.0\\GlobalTransportLabel.ttl',
#  'io.catenax.global_transport_label\\1.2.0\\GlobalTransportLabel.ttl',
#  'io.catenax.id_based_comment\\1.0.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_comment\\1.1.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_comment\\1.2.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_request_for_update\\1.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\1.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\1.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.individual_asset_definition\\2.0.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.individual_asset_definition\\2.1.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.individual_asset_definition\\2.2.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.iot_sensor_data\\2.0.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_data\\2.1.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_data\\2.2.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.0.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.1.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.2.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.item_stock\\1.0.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\1.1.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\1.2.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.0.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.1.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.2.0\\ItemStock.ttl',
#  'io.catenax.just_in_sequence_part\\2.0.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\2.1.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\2.2.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.0.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.1.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.2.0\\JustInSequencePart.ttl',
#  'io.catenax.mandatory_dismantling\\1.0.0\\MandatoryDismantling.ttl',
#  'io.catenax.mandatory_dismantling\\4.0.0\\MandatoryDismantling.ttl',
#  'io.catenax.mandatory_dismantling\\4.1.0\\MandatoryDismantling.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.0.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.1.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.2.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.3.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.4.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.5.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufacturing_capability\\2.0.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\2.1.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\2.2.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.0.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.1.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.2.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.3.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.4.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.5.0\\ManufacturingCapability.ttl',
#  'io.catenax.market_place_offer\\2.0.0\\MarketplaceOffer.ttl',
#  'io.catenax.market_place_offer\\2.1.0\\MarketplaceOffer.ttl',
#  'io.catenax.market_place_offer\\2.2.0\\MarketplaceOffer.ttl',
#  'io.catenax.material.chemical_material_passport\\1.0.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\1.1.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\1.2.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.0.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.1.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.2.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material_demand\\1.0.0\\MaterialDemand.ttl',
#  'io.catenax.material_demand\\1.1.0\\MaterialDemand.ttl',
#  'io.catenax.material_demand\\1.2.0\\MaterialDemand.ttl',
#  'io.catenax.material_flow_scenario_request\\1.0.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\1.1.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\1.2.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.0.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.1.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.2.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.0.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.1.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.2.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.0.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.1.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.2.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_for_homologation\\2.0.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_for_homologation\\2.1.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_for_homologation\\2.2.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_recycling_certificate\\1.0.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.material_recycling_certificate\\1.1.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.material_recycling_certificate\\1.2.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.packing_list\\1.0.0\\PackingList.ttl',
#  'io.catenax.packing_list\\1.1.0\\PackingList.ttl',
#  'io.catenax.packing_list\\1.2.0\\PackingList.ttl',
#  'io.catenax.parts_analyses\\2.0.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\2.1.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\2.2.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.0.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.1.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.2.0\\PartsAnalyses.ttl',
#  'io.catenax.part_as_planned\\2.0.0\\PartAsPlanned.ttl',
#  'io.catenax.part_as_planned\\2.1.0\\PartAsPlanned.ttl',
#  'io.catenax.part_as_planned\\2.2.0\\PartAsPlanned.ttl',
#  'io.catenax.part_as_specified\\3.0.0\\PartAsSpecified.ttl',
#  'io.catenax.part_as_specified\\3.1.0\\PartAsSpecified.ttl',
#  'io.catenax.part_as_specified\\3.2.0\\PartAsSpecified.ttl',
#  'io.catenax.part_site_information_as_planned\\1.0.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_site_information_as_planned\\1.1.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_site_information_as_planned\\1.2.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_type_information\\1.0.0\\PartTypeInformation.ttl',
#  'io.catenax.part_type_information\\1.1.0\\PartTypeInformation.ttl',
#  'io.catenax.part_type_information\\1.2.0\\PartTypeInformation.ttl',
#  'io.catenax.pcf\\5.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\5.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\5.2.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.2.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.2.0\\Pcf.ttl',
#  'io.catenax.planned_production_output\\1.0.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\1.1.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\1.2.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.0.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.1.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.2.0\\PlannedProductionOutput.ttl',
#  'io.catenax.product_stock\\2.0.0\\ProductStock.ttl',
#  'io.catenax.product_stock\\2.1.0\\ProductStock.ttl',
#  'io.catenax.product_stock\\2.2.0\\ProductStock.ttl',
#  'io.catenax.quality_task\\2.0.0\\QualityTask.ttl',
#  'io.catenax.quality_task\\2.1.0\\QualityTask.ttl',
#  'io.catenax.quality_task\\2.2.0\\QualityTask.ttl',
#  'io.catenax.quality_task_attachment\\1.0.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\1.1.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\1.2.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.0.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.1.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.2.0\\QualityTaskAttachment.ttl',
#  'io.catenax.refurbishing_certificate\\2.0.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\2.1.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\2.2.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.0.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.1.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.2.0\\RefurbishingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.0.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.1.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.2.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.0.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.1.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.2.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.repair_certificate\\1.0.0\\RepairCertificate.ttl',
#  'io.catenax.repair_certificate\\1.1.0\\RepairCertificate.ttl',
#  'io.catenax.repair_certificate\\1.2.0\\RepairCertificate.ttl',
#  'io.catenax.request_for_quotation\\1.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\1.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\1.2.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.2.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.2.0\\RequestForQuotation.ttl',
#  'io.catenax.return_request\\2.0.0\\ReturnRequest.ttl',
#  'io.catenax.return_request\\2.1.0\\ReturnRequest.ttl',
#  'io.catenax.return_request\\2.2.0\\ReturnRequest.ttl',
#  'io.catenax.reuse_certificate\\2.0.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\2.1.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\2.2.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.0.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.1.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.2.0\\ReuseCertificate.ttl',
#  'io.catenax.rul\\2.0.0\\RemainingUsefulLife.ttl',
#  'io.catenax.rul\\2.1.0\\RemainingUsefulLife.ttl',
#  'io.catenax.rul\\2.2.0\\RemainingUsefulLife.ttl',
#  'io.catenax.secondary_material_content\\1.0.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content\\1.1.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content\\1.2.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.0.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.1.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.2.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.0.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.1.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.2.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.serial_part\\2.0.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\2.1.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\2.2.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.0.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.1.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.2.0\\SerialPart.ttl',
#  'io.catenax.shared.address_characteristic\\3.0.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\3.1.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\3.2.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.0.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.1.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.2.0\\AddressAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.0.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.1.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.2.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.3.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.4.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.5.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.0.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.1.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.2.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.business_partner_number\\1.0.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\1.1.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\1.2.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.0.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.1.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.2.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.contact_information\\3.0.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\3.1.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\3.2.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.0.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.1.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.2.0\\ContactInformation.ttl',
#  'io.catenax.shared.message_header\\1.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\1.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\1.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.part_classification\\1.0.0\\PartClassification.ttl',
#  'io.catenax.shared.part_classification\\1.1.0\\PartClassification.ttl',
#  'io.catenax.shared.part_classification\\1.2.0\\PartClassification.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.0.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.1.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.2.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.0.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.1.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.2.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.physical_dimension\\3.0.0\\PhysicalDimensions.ttl',
#  'io.catenax.shared.physical_dimension\\3.1.0\\PhysicalDimensions.ttl',
#  'io.catenax.shared.physical_dimension\\3.2.0\\PhysicalDimensions.ttl',
#  'io.catenax.shared.quantity\\1.0.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\1.1.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\1.2.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.0.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.1.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.2.0\\Quantity.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.0.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.1.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.2.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.0.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.1.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.2.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.secondary_material_content\\1.0.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.shared.secondary_material_content\\1.1.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.0.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.1.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.2.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.0.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.1.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.2.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.uuid\\1.0.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\1.1.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\1.2.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.0.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.1.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.2.0\\Uuid.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.0.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.1.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.2.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.0.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.1.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.2.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.0.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.1.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.2.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.0.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.1.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.2.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.0.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.1.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.2.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.0.0\\ProvideProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.1.0\\ProvideProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.2.0\\ProvideProductionTracking.ttl',
#  'io.catenax.short_term_material_demand\\1.0.0\\ShortTermMaterialDemand.ttl',
#  'io.catenax.short_term_material_demand\\1.1.0\\ShortTermMaterialDemand.ttl',
#  'io.catenax.single_level_bom_as_built\\2.0.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\2.1.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\2.2.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.0.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.1.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.2.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_planned\\2.0.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\2.1.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.0.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.1.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.2.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.0.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.1.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.2.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_usage_as_built\\2.0.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\2.1.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\2.2.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.0.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.1.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.2.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.0.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.1.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.2.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.software_information\\1.0.0\\SoftwareInformation.ttl',
#  'io.catenax.software_information\\1.1.0\\SoftwareInformation.ttl',
#  'io.catenax.software_information\\1.2.0\\SoftwareInformation.ttl',
#  'io.catenax.time_series_reference\\1.0.0\\TimeSeriesReference.ttl',
#  'io.catenax.time_series_reference\\1.1.0\\TimeSeriesReference.ttl',
#  'io.catenax.time_series_reference\\1.2.0\\TimeSeriesReference.ttl',
#  'io.catenax.traction_battery_code\\2.0.0\\TractionBatteryCode.ttl',
#  'io.catenax.transmission.transmission_pass\\2.0.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\2.1.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\2.2.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.0.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.1.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.2.0\\TransmissionPass.ttl',
#  'io.catenax.user_estimated_loading\\2.0.0\\UserEstimatedLoading.ttl',
#  'io.catenax.user_estimated_loading\\2.1.0\\UserEstimatedLoading.ttl',
#  'io.catenax.user_estimated_loading\\2.2.0\\UserEstimatedLoading.ttl',
#  'io.catenax.vehicle.product_description\\3.0.0\\ProductDescription.ttl',
#  'io.catenax.vehicle.product_description\\3.1.0\\ProductDescription.ttl',
#  'io.catenax.vehicle.product_description\\3.2.0\\ProductDescription.ttl',
#  'io.catenax.waste\\2.0.0\\Waste.ttl',
#  'io.catenax.waste\\2.1.0\\Waste.ttl',
#  'io.catenax.waste\\2.2.0\\Waste.ttl',
#  'io.catenax.waste_certificate\\1.0.0\\WasteCertificate.ttl',
#  'io.catenax.waste_certificate\\1.1.0\\WasteCertificate.ttl',
#  'io.catenax.waste_certificate\\1.2.0\\WasteCertificate.ttl',
#  'io.catenax.week_based_capacity_group\\2.0.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\2.1.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\2.2.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.0.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.1.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.2.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_material_demand\\2.0.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\2.1.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\2.2.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.0.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.1.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.2.0\\WeekBasedMaterialDemand.ttl']

# %%
from sklearn.model_selection import train_test_split

base_path_list = list(base_path)
# Split into train and test (80% train, 20% test)
train_list, test_list = train_test_split(base_path_list, test_size=0.2, random_state=42)

# %%
filtered_list_train = [item for item in ttl_paths if any(substring in item for substring in train_list)]
print(len(filtered_list_train))
filtered_list_train
# Out:
# 367
# ['io.catenax.asset_tracker_links\\2.0.0\\AssetTrackerLinks.ttl',
#  'io.catenax.asset_tracker_links\\2.1.0\\AssetTrackerLinks.ttl',
#  'io.catenax.asset_tracker_links\\2.2.0\\AssetTrackerLinks.ttl',
#  'io.catenax.batch\\2.0.0\\Batch.ttl',
#  'io.catenax.batch\\2.0.1\\Batch.ttl',
#  'io.catenax.batch\\2.1.0\\Batch.ttl',
#  'io.catenax.batch\\2.1.1\\Batch.ttl',
#  'io.catenax.batch\\2.2.0\\Batch.ttl',
#  'io.catenax.batch\\2.2.1\\Batch.ttl',
#  'io.catenax.batch\\3.0.0\\Batch.ttl',
#  'io.catenax.batch\\3.1.0\\Batch.ttl',
#  'io.catenax.batch\\3.2.0\\Batch.ttl',
#  'io.catenax.battery.battery_pass\\4.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\4.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\4.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\5.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.0.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.1.0\\BatteryPass.ttl',
#  'io.catenax.battery.battery_pass\\6.2.0\\BatteryPass.ttl',
#  'io.catenax.battery.product_description\\1.0.1\\ProductDescription.ttl',
#  'io.catenax.battery.product_description\\1.1.1\\ProductDescription.ttl',
#  'io.catenax.battery.product_description\\1.2.1\\ProductDescription.ttl',
#  'io.catenax.bom_as_specified\\1.0.1\\BomAsSpecified.ttl',
#  'io.catenax.bom_as_specified\\1.1.1\\BomAsSpecified.ttl',
#  'io.catenax.bom_as_specified\\1.2.1\\BomAsSpecified.ttl',
#  'io.catenax.certificate_of_destruction\\2.0.0\\CertificateOfDestruction.ttl',
#  'io.catenax.certificate_of_destruction\\2.1.0\\CertificateOfDestruction.ttl',
#  'io.catenax.certificate_signing_requests\\1.0.0\\CertificateSigningRequests.ttl',
#  'io.catenax.certificate_signing_requests\\1.1.0\\CertificateSigningRequests.ttl',
#  'io.catenax.certificate_signing_requests\\1.2.0\\CertificateSigningRequests.ttl',
#  'io.catenax.classified_load_spectrum\\2.0.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.classified_load_spectrum\\2.1.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.classified_load_spectrum\\2.2.0\\ClassifiedLoadSpectrum.ttl',
#  'io.catenax.customs_information\\1.0.0\\CustomsInformation.ttl',
#  'io.catenax.customs_information\\1.1.0\\CustomsInformation.ttl',
#  'io.catenax.customs_information\\1.2.0\\CustomsInformation.ttl',
#  'io.catenax.days_of_supply\\1.0.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\1.1.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\1.2.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.0.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.1.0\\DaysOfSupply.ttl',
#  'io.catenax.days_of_supply\\2.2.0\\DaysOfSupply.ttl',
#  'io.catenax.decomissioning_certificate\\2.0.0\\DecommissioningCertificate.ttl',
#  'io.catenax.decomissioning_certificate\\2.1.0\\DecommissioningCertificate.ttl',
#  'io.catenax.decomissioning_certificate\\2.2.0\\DecommissioningCertificate.ttl',
#  'io.catenax.delivery_information\\1.0.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\1.1.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\1.2.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.0.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.1.0\\DeliveryInformation.ttl',
#  'io.catenax.delivery_information\\2.2.0\\DeliveryInformation.ttl',
#  'io.catenax.early_warning_notification\\1.0.0\\EarlyWarningNotification.ttl',
#  'io.catenax.early_warning_notification\\1.1.0\\EarlyWarningNotification.ttl',
#  'io.catenax.early_warning_notification\\1.2.0\\EarlyWarningNotification.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.0.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.1.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\1.2.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.0.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.1.0\\ElectricDrivePassport.ttl',
#  'io.catenax.electric_drive.electric_drive_passport\\2.2.0\\ElectricDrivePassport.ttl',
#  'io.catenax.essincident\\2.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\2.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\2.2.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\3.2.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.0.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.1.0\\EssIncident.ttl',
#  'io.catenax.essincident\\4.2.0\\EssIncident.ttl',
#  'io.catenax.failure_pattern\\1.0.0\\FailurePattern.ttl',
#  'io.catenax.failure_pattern\\1.1.0\\FailurePattern.ttl',
#  'io.catenax.failure_pattern\\1.2.0\\FailurePattern.ttl',
#  'io.catenax.fleet.claim_data\\2.0.0\\ClaimData.ttl',
#  'io.catenax.fleet.claim_data\\2.1.0\\ClaimData.ttl',
#  'io.catenax.fleet.claim_data\\2.2.0\\ClaimData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.0.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.1.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.diagnostic_data\\2.2.0\\DiagnosticData.ttl',
#  'io.catenax.fleet.vehicles\\1.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\1.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\1.2.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.2.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.3.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.4.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\2.5.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.0.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.1.0\\Vehicles.ttl',
#  'io.catenax.fleet.vehicles\\3.2.0\\Vehicles.ttl',
#  'io.catenax.generic.digital_product_passport\\2.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\2.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\2.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\3.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\4.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.0.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.1.0\\DigitalProductPassport.ttl',
#  'io.catenax.generic.digital_product_passport\\5.2.0\\DigitalProductPassport.ttl',
#  'io.catenax.id_based_comment\\1.0.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_comment\\1.1.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_comment\\1.2.0\\IdBasedComment.ttl',
#  'io.catenax.id_based_request_for_update\\1.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\1.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\1.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\2.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.0.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.1.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.id_based_request_for_update\\3.2.0\\IdBasedRequestForUpdate.ttl',
#  'io.catenax.individual_asset_definition\\2.0.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.individual_asset_definition\\2.1.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.individual_asset_definition\\2.2.0\\IndividualAssetDefinition.ttl',
#  'io.catenax.iot_sensor_data\\2.0.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_data\\2.1.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_data\\2.2.0\\IotSensorData.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.0.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.1.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.iot_sensor_device_definition\\2.2.0\\IotSensorDeviceDefinition.ttl',
#  'io.catenax.item_stock\\1.0.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\1.1.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\1.2.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.0.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.1.0\\ItemStock.ttl',
#  'io.catenax.item_stock\\2.2.0\\ItemStock.ttl',
#  'io.catenax.just_in_sequence_part\\2.0.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\2.1.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\2.2.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.0.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.1.0\\JustInSequencePart.ttl',
#  'io.catenax.just_in_sequence_part\\3.2.0\\JustInSequencePart.ttl',
#  'io.catenax.manufacturing_capability\\2.0.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\2.1.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\2.2.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.0.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.1.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.2.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.3.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.4.0\\ManufacturingCapability.ttl',
#  'io.catenax.manufacturing_capability\\3.5.0\\ManufacturingCapability.ttl',
#  'io.catenax.market_place_offer\\2.0.0\\MarketplaceOffer.ttl',
#  'io.catenax.market_place_offer\\2.1.0\\MarketplaceOffer.ttl',
#  'io.catenax.market_place_offer\\2.2.0\\MarketplaceOffer.ttl',
#  'io.catenax.material.chemical_material_passport\\1.0.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\1.1.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\1.2.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.0.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.1.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material.chemical_material_passport\\2.2.0\\ChemicalMaterialPassport.ttl',
#  'io.catenax.material_flow_scenario_request\\1.0.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\1.1.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\1.2.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.0.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.1.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_scenario_request\\2.2.0\\MaterialFlowScenarioRequestAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.0.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.1.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\2.2.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.0.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.1.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.material_flow_simulation_result\\3.2.0\\MaterialFlowSimulationResultAspect.ttl',
#  'io.catenax.parts_analyses\\2.0.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\2.1.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\2.2.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.0.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.1.0\\PartsAnalyses.ttl',
#  'io.catenax.parts_analyses\\3.2.0\\PartsAnalyses.ttl',
#  'io.catenax.part_as_specified\\3.0.0\\PartAsSpecified.ttl',
#  'io.catenax.part_as_specified\\3.1.0\\PartAsSpecified.ttl',
#  'io.catenax.part_as_specified\\3.2.0\\PartAsSpecified.ttl',
#  'io.catenax.part_site_information_as_planned\\1.0.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_site_information_as_planned\\1.1.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_site_information_as_planned\\1.2.0\\PartSiteInformationAsPlanned.ttl',
#  'io.catenax.part_type_information\\1.0.0\\PartTypeInformation.ttl',
#  'io.catenax.part_type_information\\1.1.0\\PartTypeInformation.ttl',
#  'io.catenax.part_type_information\\1.2.0\\PartTypeInformation.ttl',
#  'io.catenax.pcf\\5.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\5.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\5.2.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\6.2.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.0.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.1.0\\Pcf.ttl',
#  'io.catenax.pcf\\7.2.0\\Pcf.ttl',
#  'io.catenax.planned_production_output\\1.0.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\1.1.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\1.2.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.0.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.1.0\\PlannedProductionOutput.ttl',
#  'io.catenax.planned_production_output\\2.2.0\\PlannedProductionOutput.ttl',
#  'io.catenax.product_stock\\2.0.0\\ProductStock.ttl',
#  'io.catenax.product_stock\\2.1.0\\ProductStock.ttl',
#  'io.catenax.product_stock\\2.2.0\\ProductStock.ttl',
#  'io.catenax.quality_task\\2.0.0\\QualityTask.ttl',
#  'io.catenax.quality_task\\2.1.0\\QualityTask.ttl',
#  'io.catenax.quality_task\\2.2.0\\QualityTask.ttl',
#  'io.catenax.quality_task_attachment\\1.0.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\1.1.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\1.2.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.0.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.1.0\\QualityTaskAttachment.ttl',
#  'io.catenax.quality_task_attachment\\2.2.0\\QualityTaskAttachment.ttl',
#  'io.catenax.refurbishing_certificate\\2.0.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\2.1.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\2.2.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.0.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.1.0\\RefurbishingCertificate.ttl',
#  'io.catenax.refurbishing_certificate\\3.2.0\\RefurbishingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.0.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.1.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\2.2.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.0.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.1.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.remanufacturing_certificate\\3.2.0\\RemanufacturingCertificate.ttl',
#  'io.catenax.repair_certificate\\1.0.0\\RepairCertificate.ttl',
#  'io.catenax.repair_certificate\\1.1.0\\RepairCertificate.ttl',
#  'io.catenax.repair_certificate\\1.2.0\\RepairCertificate.ttl',
#  'io.catenax.return_request\\2.0.0\\ReturnRequest.ttl',
#  'io.catenax.return_request\\2.1.0\\ReturnRequest.ttl',
#  'io.catenax.return_request\\2.2.0\\ReturnRequest.ttl',
#  'io.catenax.rul\\2.0.0\\RemainingUsefulLife.ttl',
#  'io.catenax.rul\\2.1.0\\RemainingUsefulLife.ttl',
#  'io.catenax.rul\\2.2.0\\RemainingUsefulLife.ttl',
#  'io.catenax.secondary_material_content\\1.0.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content\\1.1.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content\\1.2.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.0.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.1.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_calculated\\1.2.0\\SecondaryMaterialContentCalculated.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.0.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.1.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.secondary_material_content_verifiable\\1.2.0\\SecondaryMaterialContentVerifiable.ttl',
#  'io.catenax.shared.address_characteristic\\3.0.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\3.1.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\3.2.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.0.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.1.0\\AddressAspect.ttl',
#  'io.catenax.shared.address_characteristic\\4.2.0\\AddressAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.0.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.1.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.2.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.3.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.4.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.bill_of_process\\1.5.0\\BillOfProcessSharedAspect.ttl',
#  'io.catenax.shared.business_partner_number\\1.0.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\1.1.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\1.2.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.0.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.1.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.business_partner_number\\2.2.0\\BusinessPartnerNumber.ttl',
#  'io.catenax.shared.contact_information\\3.0.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\3.1.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\3.2.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.0.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.1.0\\ContactInformation.ttl',
#  'io.catenax.shared.contact_information\\4.2.0\\ContactInformation.ttl',
#  'io.catenax.shared.message_header\\1.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\1.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\1.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\2.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.0.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.1.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.message_header\\3.2.0\\MessageHeaderAspect.ttl',
#  'io.catenax.shared.part_classification\\1.0.0\\PartClassification.ttl',
#  'io.catenax.shared.part_classification\\1.1.0\\PartClassification.ttl',
#  'io.catenax.shared.part_classification\\1.2.0\\PartClassification.ttl',
#  'io.catenax.shared.quantity\\1.0.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\1.1.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\1.2.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.0.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.1.0\\Quantity.ttl',
#  'io.catenax.shared.quantity\\2.2.0\\Quantity.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.0.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.1.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\2.2.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.0.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.1.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.recycling_strategy_certificate\\3.2.0\\RecyclingStrategyCertificate.ttl',
#  'io.catenax.shared.secondary_material_content\\1.0.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.shared.secondary_material_content\\1.1.0\\SecondaryMaterialContent.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.0.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.1.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\1.2.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.0.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.1.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.shopfloor_information_types\\2.2.0\\ShopfloorInformationTypes.ttl',
#  'io.catenax.shared.uuid\\1.0.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\1.1.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\1.2.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.0.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.1.0\\Uuid.ttl',
#  'io.catenax.shared.uuid\\2.2.0\\Uuid.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.0.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.1.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\1.2.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.0.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.1.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_forecast\\2.2.0\\GetProductionForecast.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.0.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.1.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.get_production_tracking\\1.2.0\\GetProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.0.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.1.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\1.2.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.0.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.1.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_forecast\\2.2.0\\ProvideProductionForecast.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.0.0\\ProvideProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.1.0\\ProvideProductionTracking.ttl',
#  'io.catenax.shopfloor_information.provide_production_tracking\\1.2.0\\ProvideProductionTracking.ttl',
#  'io.catenax.single_level_bom_as_planned\\2.0.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\2.1.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.0.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.1.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_planned\\3.2.0\\SingleLevelBomAsPlanned.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.0.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.1.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_bom_as_specified\\2.2.0\\SingleLevelBomAsSpecified.ttl',
#  'io.catenax.single_level_usage_as_built\\2.0.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\2.1.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\2.2.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.0.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.1.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_built\\3.2.0\\SingleLevelUsageAsBuilt.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.0.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.1.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.single_level_usage_as_planned\\2.2.0\\SingleLevelUsageAsPlanned.ttl',
#  'io.catenax.software_information\\1.0.0\\SoftwareInformation.ttl',
#  'io.catenax.software_information\\1.1.0\\SoftwareInformation.ttl',
#  'io.catenax.software_information\\1.2.0\\SoftwareInformation.ttl',
#  'io.catenax.time_series_reference\\1.0.0\\TimeSeriesReference.ttl',
#  'io.catenax.time_series_reference\\1.1.0\\TimeSeriesReference.ttl',
#  'io.catenax.time_series_reference\\1.2.0\\TimeSeriesReference.ttl',
#  'io.catenax.traction_battery_code\\2.0.0\\TractionBatteryCode.ttl',
#  'io.catenax.transmission.transmission_pass\\2.0.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\2.1.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\2.2.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.0.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.1.0\\TransmissionPass.ttl',
#  'io.catenax.transmission.transmission_pass\\3.2.0\\TransmissionPass.ttl',
#  'io.catenax.user_estimated_loading\\2.0.0\\UserEstimatedLoading.ttl',
#  'io.catenax.user_estimated_loading\\2.1.0\\UserEstimatedLoading.ttl',
#  'io.catenax.user_estimated_loading\\2.2.0\\UserEstimatedLoading.ttl',
#  'io.catenax.vehicle.product_description\\3.0.0\\ProductDescription.ttl',
#  'io.catenax.vehicle.product_description\\3.1.0\\ProductDescription.ttl',
#  'io.catenax.vehicle.product_description\\3.2.0\\ProductDescription.ttl',
#  'io.catenax.waste\\2.0.0\\Waste.ttl',
#  'io.catenax.waste\\2.1.0\\Waste.ttl',
#  'io.catenax.waste\\2.2.0\\Waste.ttl',
#  'io.catenax.waste_certificate\\1.0.0\\WasteCertificate.ttl',
#  'io.catenax.waste_certificate\\1.1.0\\WasteCertificate.ttl',
#  'io.catenax.waste_certificate\\1.2.0\\WasteCertificate.ttl',
#  'io.catenax.week_based_material_demand\\2.0.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\2.1.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\2.2.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.0.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.1.0\\WeekBasedMaterialDemand.ttl',
#  'io.catenax.week_based_material_demand\\3.2.0\\WeekBasedMaterialDemand.ttl']

# %%
filtered_list_test = [item for item in ttl_paths if any(substring in item for substring in test_list)]
print(len(filtered_list_test))
filtered_list_test
# Out:
# 86
# ['io.catenax.certificate_of_dismantler\\1.0.1\\CertificateOfDismantler.ttl',
#  'io.catenax.certificate_of_dismantler\\1.1.1\\CertificateOfDismantler.ttl',
#  'io.catenax.certificate_of_dismantler\\1.2.1\\CertificateOfDismantler.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.0.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.1.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\1.2.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.0.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.1.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.demand_and_capacity_notification\\2.2.0\\DemandAndCapacityNotification.ttl',
#  'io.catenax.eol_story\\2.0.0\\EndOfLife.ttl',
#  'io.catenax.eol_story\\2.1.0\\EndOfLife.ttl',
#  'io.catenax.eol_story\\2.2.0\\EndOfLife.ttl',
#  'io.catenax.global_transport_label\\1.0.0\\GlobalTransportLabel.ttl',
#  'io.catenax.global_transport_label\\1.1.0\\GlobalTransportLabel.ttl',
#  'io.catenax.global_transport_label\\1.2.0\\GlobalTransportLabel.ttl',
#  'io.catenax.mandatory_dismantling\\1.0.0\\MandatoryDismantling.ttl',
#  'io.catenax.mandatory_dismantling\\4.0.0\\MandatoryDismantling.ttl',
#  'io.catenax.mandatory_dismantling\\4.1.0\\MandatoryDismantling.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.0.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.1.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.2.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.3.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.4.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.manufactured_parts_quality_information\\2.5.0\\ManufacturedPartsQualityInformation.ttl',
#  'io.catenax.material_demand\\1.0.0\\MaterialDemand.ttl',
#  'io.catenax.material_demand\\1.1.0\\MaterialDemand.ttl',
#  'io.catenax.material_demand\\1.2.0\\MaterialDemand.ttl',
#  'io.catenax.material_for_homologation\\2.0.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_for_homologation\\2.1.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_for_homologation\\2.2.0\\MaterialForHomologation.ttl',
#  'io.catenax.material_recycling_certificate\\1.0.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.material_recycling_certificate\\1.1.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.material_recycling_certificate\\1.2.0\\MaterialRecyclingCertificate.ttl',
#  'io.catenax.packing_list\\1.0.0\\PackingList.ttl',
#  'io.catenax.packing_list\\1.1.0\\PackingList.ttl',
#  'io.catenax.packing_list\\1.2.0\\PackingList.ttl',
#  'io.catenax.part_as_planned\\2.0.0\\PartAsPlanned.ttl',
#  'io.catenax.part_as_planned\\2.1.0\\PartAsPlanned.ttl',
#  'io.catenax.part_as_planned\\2.2.0\\PartAsPlanned.ttl',
#  'io.catenax.request_for_quotation\\1.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\1.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\1.2.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\2.2.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.0.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.1.0\\RequestForQuotation.ttl',
#  'io.catenax.request_for_quotation\\3.2.0\\RequestForQuotation.ttl',
#  'io.catenax.reuse_certificate\\2.0.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\2.1.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\2.2.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.0.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.1.0\\ReuseCertificate.ttl',
#  'io.catenax.reuse_certificate\\3.2.0\\ReuseCertificate.ttl',
#  'io.catenax.serial_part\\2.0.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\2.1.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\2.2.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.0.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.1.0\\SerialPart.ttl',
#  'io.catenax.serial_part\\3.2.0\\SerialPart.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.0.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.1.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.business_partner_certificate\\1.2.0\\BusinessPartnerCertificate.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.0.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.1.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\1.2.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.0.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.1.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.part_site_information_as_built\\2.2.0\\PartSiteInformationAsBuilt.ttl',
#  'io.catenax.shared.physical_dimension\\3.0.0\\PhysicalDimensions.ttl',
#  'io.catenax.shared.physical_dimension\\3.1.0\\PhysicalDimensions.ttl',
#  'io.catenax.shared.physical_dimension\\3.2.0\\PhysicalDimensions.ttl',
#  'io.catenax.short_term_material_demand\\1.0.0\\ShortTermMaterialDemand.ttl',
#  'io.catenax.short_term_material_demand\\1.1.0\\ShortTermMaterialDemand.ttl',
#  'io.catenax.single_level_bom_as_built\\2.0.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\2.1.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\2.2.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.0.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.1.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.single_level_bom_as_built\\3.2.0\\SingleLevelBomAsBuilt.ttl',
#  'io.catenax.week_based_capacity_group\\2.0.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\2.1.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\2.2.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.0.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.1.0\\WeekBasedCapacityGroup.ttl',
#  'io.catenax.week_based_capacity_group\\3.2.0\\WeekBasedCapacityGroup.ttl']

# %% [markdown]
# Construct CSV files from splited file path.

# %%
import csv

csv_file = "train_2024-09-05.csv"

with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(["JSON_paths", "TTL_paths"])
    
    for ttl in filtered_list_train:
        ttl_path = Path(ttl)
        file_name = ttl_path.stem  
        json = ttl_path.parent / "gen" / f"{file_name}.json"
        writer.writerow([json, ttl])

print(f"Data has been written to {csv_file}")
# Out:
# Data has been written to train_2024-09-05.csv

# %%
def create_csv(csv_file, data_list):
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)

        writer.writerow(["JSON_paths", "TTL_paths"])

        for ttl in data_list:
            ttl_path = Path(ttl)
            file_name = ttl_path.stem  
            json = ttl_path.parent / "gen" / f"{file_name}.json"
            writer.writerow([json, ttl])

    print(f"Data has been written to {csv_file}")
    
    
csv_file = "test_2024-09-05.csv"
create_csv(csv_file, filtered_list_test)
# Out:
# Data has been written to test_2024-09-05.csv

# %%
test_list
# Out:
# ['io.catenax.item_stock',
#  'io.catenax.reuse_certificate',
#  'io.catenax.part_as_planned',
#  'io.catenax.shared.bill_of_process',
#  'io.catenax.manufactured_parts_quality_information',
#  'io.catenax.fleet.diagnostic_data',
#  'io.catenax.material.chemical_material_passport',
#  'io.catenax.transmission.transmission_pass',
#  'io.catenax.certificate_of_destruction',
#  'io.catenax.shared.quantity']

# %%
base_path
# Out:
# {'io.catenax.asset_tracker_links',
#  'io.catenax.batch',
#  'io.catenax.battery.battery_pass',
#  'io.catenax.battery.product_description',
#  'io.catenax.bom_as_specified',
#  'io.catenax.certificate_of_destruction',
#  'io.catenax.certificate_of_dismantler',
#  'io.catenax.certificate_signing_requests',
#  'io.catenax.classified_load_spectrum',
#  'io.catenax.customs_information',
#  'io.catenax.days_of_supply',
#  'io.catenax.decomissioning_certificate',
#  'io.catenax.delivery_information',
#  'io.catenax.demand_and_capacity_notification',
#  'io.catenax.early_warning_notification',
#  'io.catenax.electric_drive.electric_drive_passport',
#  'io.catenax.eol_story',
#  'io.catenax.essincident',
#  'io.catenax.failure_pattern',
#  'io.catenax.fleet.claim_data',
#  'io.catenax.fleet.diagnostic_data',
#  'io.catenax.fleet.vehicles',
#  'io.catenax.generic.digital_product_passport',
#  'io.catenax.global_transport_label',
#  'io.catenax.id_based_comment',
#  'io.catenax.id_based_request_for_update',
#  'io.catenax.individual_asset_definition',
#  'io.catenax.iot_sensor_data',
#  'io.catenax.iot_sensor_device_definition',
#  'io.catenax.item_stock',
#  'io.catenax.just_in_sequence_part',
#  'io.catenax.mandatory_dismantling',
#  'io.catenax.manufactured_parts_quality_information',
#  'io.catenax.manufacturing_capability',
#  'io.catenax.market_place_offer',
#  'io.catenax.material.chemical_material_passport',
#  'io.catenax.material_demand',
#  'io.catenax.material_flow_scenario_request',
#  'io.catenax.material_flow_simulation_result',
#  'io.catenax.material_for_homologation',
#  'io.catenax.material_recycling_certificate',
#  'io.catenax.packing_list',
#  'io.catenax.part_as_planned',
#  'io.catenax.part_as_specified',
#  'io.catenax.part_site_information_as_planned',
#  'io.catenax.part_type_information',
#  'io.catenax.parts_analyses',
#  'io.catenax.pcf',
#  'io.catenax.planned_production_output',
#  'io.catenax.product_stock',
#  'io.catenax.quality_task',
#  'io.catenax.quality_task_attachment',
#  'io.catenax.refurbishing_certificate',
#  'io.catenax.remanufacturing_certificate',
#  'io.catenax.repair_certificate',
#  'io.catenax.request_for_quotation',
#  'io.catenax.return_request',
#  'io.catenax.reuse_certificate',
#  'io.catenax.rul',
#  'io.catenax.secondary_material_content',
#  'io.catenax.secondary_material_content_calculated',
#  'io.catenax.secondary_material_content_verifiable',
#  'io.catenax.serial_part',
#  'io.catenax.shared.address_characteristic',
#  'io.catenax.shared.bill_of_process',
#  'io.catenax.shared.business_partner_certificate',
#  'io.catenax.shared.business_partner_number',
#  'io.catenax.shared.contact_information',
#  'io.catenax.shared.message_header',
#  'io.catenax.shared.part_classification',
#  'io.catenax.shared.part_site_information_as_built',
#  'io.catenax.shared.physical_dimension',
#  'io.catenax.shared.quantity',
#  'io.catenax.shared.recycling_strategy_certificate',
#  'io.catenax.shared.secondary_material_content',
#  'io.catenax.shared.shopfloor_information_types',
#  'io.catenax.shared.uuid',
#  'io.catenax.shopfloor_information.get_production_forecast',
#  'io.catenax.shopfloor_information.get_production_tracking',
#  'io.catenax.shopfloor_information.provide_production_forecast',
#  'io.catenax.shopfloor_information.provide_production_tracking',
#  'io.catenax.short_term_material_demand',
#  'io.catenax.single_level_bom_as_built',
#  'io.catenax.single_level_bom_as_planned',
#  'io.catenax.single_level_bom_as_specified',
#  'io.catenax.single_level_usage_as_built',
#  'io.catenax.single_level_usage_as_planned',
#  'io.catenax.software_information',
#  'io.catenax.time_series_reference',
#  'io.catenax.traction_battery_code',
#  'io.catenax.transmission.transmission_pass',
#  'io.catenax.user_estimated_loading',
#  'io.catenax.vehicle.product_description',
#  'io.catenax.waste',
#  'io.catenax.waste_certificate',
#  'io.catenax.week_based_capacity_group',
#  'io.catenax.week_based_material_demand'}

# %%
len(ttl_paths)
# Out:
# 453

# %%
len(json_paths)
# Out:
# 453

# %% [markdown]
# # Aggregate
# After running the experiments using the inference module, this code will collect and aggregate the results

# %% [markdown]
# ## Version 1
# This script performs the following tasks:
#
# 1. **Read and Filter Text Files**:
#    - It traverses a specified folder structure (`root_folder`) to locate `summary.txt` files.
#    - Filters the files based on matching `model_name`, `inference_type`, and `experiment_name`.
#
# 2. **Aggregate Data**:
#    - Reads data from the filtered files, ensuring valid entries with exactly 4 columns.
#    - Appends each entry with the file's path for context.
#
# 3. **Write to CSV**:
#    - Writes the aggregated data, along with column headers, into a CSV file (`output_csv`), named based on the experiment, model, and inference type.

# %%
import os
import csv
from pathlib import Path

model_name = "azuregpt4o20240806SemanticAspectMetaModelV1"
inference_type = "FewShotPromptTemplate1"
experiment_name = "Test2"

def read_and_aggregate_txt_files(root_folder, output_csv):
    # List to hold the aggregated data
    aggregated_data = []
    csv_header = ['model', 'isTurtle', 'isSAMM', 'isJSON', 'filePath']

    # Traverse the folder structure
    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file.endswith('summary.txt'):
                file_path = os.path.join(subdir, file)
                path = Path(file_path)
                inference_part = path.parent.name
                # Extract experiment's name (two levels up from the file)
                experiment_part = path.parent.parent.parent.name
    
                # Extract model name (one level up from the file)
                model_part = path.parent.parent.name
                if (model_part != model_name or inference_part != inference_type or experiment_part != experiment_name):
                    continue
                with open(file_path, 'r') as f:
                    lines = f.readlines()
                    for line in lines[1:]:  # Skip the header line
                        # Split by commas to extract the data
                        data = line.strip().split(',')
                        if len(data) == 4:  # Ensure that there are exactly 4 columns
                            # Append file path to the data
                            data.append(file_path)
                            aggregated_data.append(data)

    # Write the aggregated data into a CSV file
    with open(output_csv, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(csv_header)
        writer.writerows(aggregated_data)

    print(f"Aggregated data written to {output_csv}")


root_folder = 'D:\\NMT Thesis\\Results'
output_csv = f'aggregated_summary_data_{experiment_name}_{model_name}_{inference_type}.csv'

read_and_aggregate_txt_files(root_folder, output_csv)
# Out:
# Aggregated data written to aggregated_summary_data_Test2_azuregpt4o20240806SemanticAspectMetaModelV1_FewShotPromptTemplate1.csv

# %%
import pandas as pd 
import matplotlib as mp
df = pd.read_csv(f"aggregated_summary_data_{experiment_name}_{model_name}_{inference_type}.csv")
df = df[['isTurtle','isSAMM','isJSON']]
counts = df.apply(pd.Series.value_counts)

# Filling NaN values with 0 (in case a column has no True or False)
counts = counts.fillna(0).astype(int)

# %%
counts
# Out:
#        isTurtle  isSAMM  isJSON
# False        14      63      72
# True         82      33      24

# %%
import pandas as pd

# Load CSV file
df = pd.read_csv(f"aggregated_summary_data_{experiment_name}_{model_name}_{inference_type}.csv")
# Filter rows where isJSON is True and isSAMM is False
filtered_df = df[(df['isJSON'] == True) & (df['isSAMM'] == False)]

# %%
filtered_df

# %%
df
# Out:
#                                                 model  isTurtle  isSAMM  \
# 0    io.catenax.days_of_supply/1.0.0/gen/DaysOfSupply      True    True
# 1    io.catenax.days_of_supply/1.1.0/gen/DaysOfSupply      True   False
# 2    io.catenax.days_of_supply/1.2.0/gen/DaysOfSupply      True   False
# 3    io.catenax.days_of_supply/2.0.0/gen/DaysOfSupply      True   False
# 4    io.catenax.days_of_supply/2.1.0/gen/DaysOfSupply      True    True
# ..                                                ...       ...     ...
# 91  io.catenax.week_based_capacity_group/2.1.0/gen...      True    True
# 92  io.catenax.week_based_capacity_group/2.2.0/gen...      True    True
# 93  io.catenax.week_based_capacity_group/3.0.0/gen...      True   False
# 94  io.catenax.week_based_capacity_group/3.1.0/gen...      True    True
# 95  io.catenax.week_based_capacity_group/3.2.0/gen...      True    True
#
#     isJSON  passAt                                           filePath
# 0     True       4  D:\NMT Thesis\Results\io.catenax.days_of_suppl...
# 1    False       6  D:\NMT Thesis\Results\io.catenax.days_of_suppl...
# 2    False       6  D:\NMT Thesis\Results\io.catenax.days_of_suppl...
# 3    False       6  D:\NMT Thesis\Results\io.catenax.days_of_suppl...
# 4     True       1  D:\NMT Thesis\Results\io.catenax.days_of_suppl...
# ..     ...     ...                                                ...
# 91   False       6  D:\NMT Thesis\Results\io.catenax.week_based_ca...
# 92    True       2  D:\NMT Thesis\Results\io.catenax.week_based_ca...
# 93   False       6  D:\NMT Thesis\Results\io.catenax.week_based_ca...
# 94    True       2  D:\NMT Thesis\Results\io.catenax.week_based_ca...
# 95   False       6  D:\NMT Thesis\Results\io.catenax.week_based_ca...
#
# [96 rows x 6 columns]

# %% [markdown]
# ## Version 2
# - Works with new version that contains `passAt` information.
# - Aggregated data saved to `output_csv`.
# - Displays counts for `isTurtle`, `isSAMM`, `isJSON`, and `passAt` summary.

# %%
import os
import csv
from pathlib import Path
import pandas as pd

model_name = "qwen25codersammv2latest"
inference_type = "ZeroShotPromptTemplate0"
experiment_name = "T07-FineTunedQwenv2"

def read_and_aggregate_txt_files(root_folder, output_csv):
    # List to hold the aggregated data
    aggregated_data = []
    csv_header = ['model', 'isTurtle', 'isSAMM', 'isJSON','passAt', 'filePath']

    # Traverse the folder structure
    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file=='summary.txt':
                file_path = os.path.join(subdir, file)
                path = Path(file_path)
                inference_part = path.parent.name
                # Extract experiment's name (two levels up from the file)
                experiment_part = path.parent.parent.parent.name
    
                # Extract model name (one level up from the file)
                model_part = path.parent.parent.name
                if (model_part != model_name or inference_part != inference_type or experiment_part != experiment_name):
                    continue
                with open(file_path, 'r') as f:
                    lines = f.readlines()
                    for line in lines[1:]:  # Skip the header line
                        # Split by commas to extract the data
                        data = line.strip().split(',')
                        if len(data) == 5:  # Ensure that there are exactly 4 columns
                            # Append file path to the data
                            data.append(file_path)
                            aggregated_data.append(data)
                        else:
                            print('wrong')

    # Write the aggregated data into a CSV file
    with open(os.path.join(root_folder,output_csv), 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(csv_header)
        writer.writerows(aggregated_data)

    print(f"Aggregated data written to {output_csv}")


root_folder = 'D:\\NMT Thesis\\Results'
output_csv = f'aggregated_summary_data_{experiment_name}_{model_name}_{inference_type}.csv'

read_and_aggregate_txt_files(root_folder, output_csv)

df = pd.read_csv(os.path.join(root_folder,output_csv))
counts = df[['isTurtle','isSAMM','isJSON']].apply(pd.Series.value_counts)

# Filling NaN values with 0 (in case a column has no True or False)
counts = counts.fillna(0).astype(int).sort_index()
print(model_name)
display(counts)
result_passAt = pd.DataFrame(df[df['isJSON']==True]['passAt'].value_counts()).sort_index()
display(result_passAt)
# Out:
# Aggregated data written to aggregated_summary_data_T07-FineTunedQwenv2_qwen25codersammv2latest_ZeroShotPromptTemplate0.csv
# qwen25codersammv2latest
#        isTurtle  isSAMM  isJSON
# False        43      91      95
# True         53       5       1
#    passAt
# 1       1
